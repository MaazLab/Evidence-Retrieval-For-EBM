# %%
import pandas as pd

# %%
pmcids = ['PMC2878469', 'PMC7223555', 'PMC5054555', 'PMC4491048',
          'PMC7088979', 'PMC7120988', 'PMC7297083', 'PMC7169818',
        #   'PMC5850077', 'PMC6640306', 'PMC2949385', 'PMC7080151', 'PMC7277096', 'PMC7080151', 'PMC7303941', 'PMC6969462',
          'PMC7276339', 'PMC2992996', 'PMC7088305', 'PMC7123853',
          'PMC4129829', 'PMC4708214', 'PMC7120483',
        #   'PMC7119989', 'PMC4633431', 'PMC5296266',
          'PMC4886426', 'PMC7184712', 'PMC4637959', 'PMC4637959',
          'PMC7169866', 'PMC6093684', 'PMC2875942', 'PMC7182644', 'PMC4001290',
          'PMC4748590', 'PMC5627236', 'PMC6290738', 'PMC4211021', 'PMC6083907',
          'PMC7166674', 'PMC5358466', 'PMC3003998',
          'PMC7188049', 'PMC2957877', 'PMC5119454', 'PMC7133233',
          'PMC5890575', 'PMC5923478', 'PMC6201103',
          'PMC7038234', 'PMC2990691', 'PMC5923478', 'PMC6320907',
          'PMC7361360', 'PMC4678103', 'PMC7314270', 'PMC7161860',
          'PMC4820114', 'PMC5850442', 'PMC3292390',
          'PMC7088673', 'PMC5016531', 'PMC7138456', 'PMC7357263',
          'PMC5755876', 'PMC3128050', 'PMC7086696',
          'PMC7352537', 'PMC7184394', 'PMC3270559', 'PMC7301047',
          'PMC6920537', 'PMC7122497', 'PMC7223819',
          'PMC7178857', 'PMC5907417', 'PMC7096894', 'PMC7101778', 'PMC5727246',
          'PMC7087157', 'PMC7122385', 'PMC7167668', 'PMC7120754', 'PMC5315308',
          'PMC3693993', 'PMC3285078', 'PMC5496227', 'PMC5705692']

# %%
data_df = pd.read_csv('data.csv')
data_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       pmcid                      doi  \
# 0             0           0   PMC137267            10.1186/cc987
# 1             1           1   PMC137274           10.1186/cc1013
# 2             2           2  PMC1475929      10.1093/ecam/nel003
# 3             3           3  PMC1481583   10.1186/1465-9921-7-74
# 4             4           4  PMC1525174  10.1186/1471-2458-6-126
#
#                                                title  \
# 0  Debate: Transfusing to normal haemoglobin leve...
# 1  The 21st International Symposium on Intensive ...
# 2  Epicatechins Purified from Green Tea (Camellia...
# 3  Markers of exacerbation severity in chronic ob...
# 4  Transmission patterns of smallpox: systematic ...
#
#                                             abstract publish_time  \
# 0  Recent evidence suggests that critically ill p...   2001-03-08
# 1  The 21st International Symposium on Intensive ...   2001-05-02
# 2  The anticancer potential of catechins derived ...   2006-04-25
# 3  BACKGROUND: Patients with chronic obstructive ...   2006-05-10
# 4  BACKGROUND: Because smallpox (variola major) m...   2006-05-05
#
#                                              authors  \
# 0    Alvarez, Gonzalo; Hébert, Paul C; Szick, Sharyn
# 1                      Ball, Jonathan; Venn, Richard
# 2  Ravindranath, Mepur H.; Saravanan, Thiruverkad...
# 3  Franciosi, Luigi G; Page, Clive P; Celli, Bart...
# 4  Bhatnagar, Vibha; Stoto, Michael A; Morton, Sa...
#
#                               journal  citations  author_h_index  \
# 0                           Crit Care         42              93
# 1                           Crit Care          5              30
# 2  Evid Based Complement Alternat Med          0               9
# 3                          Respir Res        106             128
# 4                   BMC Public Health          0              52
#
#    author_citations                        issn
# 0             41828               ['1364-8535']
# 1              8396               ['1364-8535']
# 2               355  ['1741-427X', '1741-4288']
# 3             81730               ['1465-993X']
# 4              9883               ['1471-2458']

# %%
relevant_papers_on_query_dataset = data_df[data_df['pmcid'].isin(pmcids)]

# %%
relevant_papers_on_query_dataset
# Out:
#       Unnamed: 0.1  Unnamed: 0       pmcid  \
# 24              24          24  PMC2990691
# 27              27          27  PMC3003998
# 53              53          53  PMC3270559
# 106            106         106  PMC4001290
# 120            120         120  PMC4129829
# ...            ...         ...         ...
# 3124          3379        3379  PMC7086696
# 3185          3440        3440  PMC6201103
# 3212          3467        3467  PMC7184394
# 3241          3497        3497  PMC4678103
# 3262          3518        3518  PMC7297083
#
#                                             doi  \
# 24                 10.1371/journal.pntd.0000892
# 27                          10.1155/2010/817580
# 53                          10.1155/2012/594361
# 106                          10.1093/cid/ciu134
# 120   10.5847/wjem.j.issn.1920-8642.2013.02.002
# ...                                         ...
# 3124                  10.1007/s00431-006-0233-x
# 3185                       10.1128/aac.01206-18
# 3212                        10.1093/cvr/cvaa093
# 3241                         10.1093/cid/civ680
# 3262                   10.3389/fimmu.2020.01100
#
#                                                   title  \
# 24    Antiviral and Neuroprotective Role of Octaguan...
# 27    Therapeutic Vaccination in Chronic Hepatitis B...
# 53    Protective Role of the ACE2/Ang-(1–9) Axis in ...
# 106   Parainfluenza Virus Lower Respiratory Tract Di...
# 120   The potential contributions of traditional Chi...
# ...                                                 ...
# 3124         Acute otitis media and respiratory viruses
# 3185  The Small-Compound Inhibitor K22 Displays Broa...
# 3212  The role of angiotensin-converting enzyme 2 in...
# 3241  The Use of Ebola Convalescent Plasma to Treat ...
# 3262  Interaction Between Virus-Like Particles (VLPs...
#
#                                                abstract publish_time  \
# 24    BACKGROUND: Japanese encephalitis (JE), caused...   2010-11-23
# 27    Recommended treatment of chronic hepatitis B w...   2010-09-07
# 53    Despite reduction in cardiovascular (CV) event...   2012-01-19
# 106   Background. Parainfluenza virus (PIV) commonly...   2014-03-05
# 120   BACKGROUND: Despite the fact that traditional ...         2013
# ...                                                 ...          ...
# 3124  The present study was performed to elucidate t...   2006-09-12
# 3185  The virus family Flaviviridae encompasses seve...   2018-10-24
# 3212  Angiotensin-converting enzyme 2 (ACE2) has eme...   2020-04-08
# 3241  The clinical evaluation of convalescent plasma...   2016-01-01
# 3262  Virus-like particles (VLPs) have been shown to...   2020-06-09
#
#                                                 authors  \
# 24          Nazmi, Arshed; Dutta, Kallol; Basu, Anirban
# 27    Kosinska, Anna D.; Zhang, Ejuan; Lu, Mengji; R...
# 53                 Ocaranza, María Paz; Jalil, Jorge E.
# 106   Seo, Sachiko; Xie, Hu; Campbell, Angela P.; Ku...
# 120                              He, Jun; Hou, Xiang-yu
# ...                                                 ...
# 3124  Bulut, Yunus; Güven, Mehmet; Otlu, Bariş; Yeni...
# 3185  García-Nicolás, Obdulio; V'kovski, Philip; Vie...
# 3212                               Chen, Li; Hao, Guang
# 3241  van Griensven, Johan; De Weiggheleire, Anja; D...
# 3262  Zepeda-Cervantes, Jesús; Ramírez-Jarquín, Josu...
#
#                            journal  citations  author_h_index  \
# 24              PLoS Negl Trop Dis         47              54
# 27                 Hepat Res Treat         28              57
# 53                 Int J Hypertens         72              40
# 106   Clinical Infectious Diseases        110             122
# 120              World J Emerg Med         17              31
# ...                            ...        ...             ...
# 3124                 Eur J Pediatr         87              32
# 3185   Antimicrob Agents Chemother          0              15
# 3212                Cardiovasc Res         93              24
# 3241               Clin Infect Dis        101              26
# 3262                 Front Immunol        121               9
#
#       author_citations                        issn
# 24                9140               ['1935-2735']
# 27               15913  ['2090-1364', '2090-1372']
# 53                6885  ['2090-0384', '2090-0392']
# 106              52942  ['1058-4838', '1537-6591']
# 120               3570               ['1920-8642']
# ...                ...                         ...
# 3124              4109  ['0340-6199', '1432-1076']
# 3185               761  ['0066-4804', '1098-6596']
# 3212              3219  ['0008-6363', '1755-3245']
# 3241              3536  ['1058-4838', '1537-6591']
# 3262               405               ['1664-3224']
#
# [70 rows x 13 columns]

# %%
relevant_papers_on_query_dataset[['pmcid','title','abstract']].to_csv('relevant_papers_of_query_dataset.csv',index=False)
